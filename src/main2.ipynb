# %%
# !pip3 install keras
import numpy
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
import matplotlib.pyplot as plt


# the data, split between train and test sets
from keras.utils import np_utils
from matplotlib import pyplot
from sklearn.model_selection import KFold
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.optimizers import SGD

# import MNIST dataset
from keras.datasets import mnist

# %%
def input_data():

    (X_train, y_train), (X_test, y_test) = mnist.load_data()

    # Reshape to be samples*pixels*width*height
    X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
    X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')


    # One hot Code
    # https://machinelearningmastery.com/how-to-one-hot-encode-sequence-data-in-python/
    y_train = np_utils.to_categorical(y_train)
    y_test = np_utils.to_categorical(y_test)
    num_classes = y_test.shape[1]

    # convert from integers to floats
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    # normalize to range [0, 1]
    X_train = (X_train / 255.0)
    X_test = (X_test / 255.0)

    return X_test, y_test, X_train, y_train

# %%
# Flatten the images.
# Flatten each 28x28 image into a 784 dimensional vector

def create_model():
    # Create model
    # Building CNN
    model = Sequential()

    model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', input_shape=(28, 28, 1)))
    
    model.add(MaxPooling2D((2, 2)))

    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform'))

    model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform'))

    model.add(MaxPooling2D((2, 2)))

    model.add(Flatten())

    model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))

    model.add(Dense(10, activation='softmax'))

    model.summary()

    # compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
# -------when you dont want to evaluate the model-------------
# model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200)

# # Final evaluation of the model
# scores = model.evaluate(X_test, y_test, verbose=0)
# print("Large CNN Error: %.2f%%" % (100-scores[1]*100))

# -------------------------------------------------------------

# -------evaluate a model using k-fold cross-validation--------
def evaluate_model(X_train, y_Train, n_folds=5):

    accuracy, data = list(), list()

    # prepare 5-cross validation
    kfold = KFold(n_folds, shuffle=True, random_state=1)

    for x_train, x_test in kfold.split(X_train):
        # create model
        model = create_model()
        # select rows for train and test
        trainX, trainY, testX, testY = X_train[x_train], y_Train[x_train], X_train[x_test], y_Train[x_test]
        # fit model
        data_fit = model.fit(trainX, trainY, validation_data=(testX, testY), epochs=10, batch_size=32)
        # evaluate model
        _, acc = model.evaluate(testX, testY, verbose=0)
        # stores accuracy
        accuracy.append(acc)
        data.append(data_fit)
    return accuracy, data

# %%
# plot diagnostic learning curves
def summarize_diagnostics(data):
    for i in range(len(data)):
        # plot loss
        pyplot.subplot(2, 1, 1)
        pyplot.title('Cross Entropy Loss')
        pyplot.plot(data[i].history['loss'], color='red', label='green')
        pyplot.plot(data[i].history['val_loss'], color='orange', label='test')
        # plot accuracy
        pyplot.subplot(2, 1, 2)
        pyplot.title('Classification Accuracy')
        pyplot.plot(data[i].history['accuracy'], color='blue', label='train')
        pyplot.plot(data[i].history['val_accuracy'], color='orange', label='test')
    pyplot.show()

# %%
# summarize model performance
def summarize_performance(acc):
    # print summary
    print('Accuracy: mean=%.3f std=%.3f, n=%d' % (numpy.mean(acc) * 100, numpy.std(acc) * 100, len(acc)))

    # box and whisker plots of results
    pyplot.boxplot(acc)
    pyplot.show()

# %%
# This function predicts the images already in the dataset
def test(X_train, model):
    test_images = X_train[1:5]
    test_images = test_images.reshape(test_images.shape[0], 28, 28)

    for i, test_image in enumerate(test_images, start=1):
        org_image = test_image
        test_image = test_image.reshape(1, 28, 28, 1)
        prediction = model.predict_classes(test_image, verbose=0)

        print("Predicted digit: {}".format(prediction[0]))
        plt.subplot(220 + i)
        plt.axis('off')
        plt.title("Predicted digit: {}".format(prediction[0]))
        plt.imshow(org_image, cmap=plt.get_cmap('gray'))

    plt.show()

# %%
def run():
    X_test, y_test, X_train, y_train = input_data()

    # Evaluate
    accuracy, data = evaluate_model(X_train, y_train)
    summarize_diagnostics(data)
    summarize_performance(accuracy)
    model = create_model()
    model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200)
    # TEST
    # for images alreday
    test(X_train, model)

    # serialize model to JSON
    model_json = model.to_json()
    with open("model.json", "w") as json_file:
        json_file.write(model_json)
    # serialize weights to HDF5
    model.save_weights("model.h5")
    print("Saved model to disk")




run()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_24 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 100)               102500
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 159,254
# Trainable params: 159,254
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.1230 - accuracy: 0.9617 - val_loss: 0.0820 - val_accuracy: 0.9762
# Epoch 2/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0430 - accuracy: 0.9868 - val_loss: 0.0518 - val_accuracy: 0.9852
# Epoch 3/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0292 - accuracy: 0.9901 - val_loss: 0.0432 - val_accuracy: 0.9879
# Epoch 4/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0218 - accuracy: 0.9926 - val_loss: 0.0479 - val_accuracy: 0.9868
# Epoch 5/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0167 - accuracy: 0.9948 - val_loss: 0.0541 - val_accuracy: 0.9862
# Epoch 6/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.0418 - val_accuracy: 0.9888
# Epoch 7/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0123 - accuracy: 0.9961 - val_loss: 0.0492 - val_accuracy: 0.9880
# Epoch 8/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0088 - accuracy: 0.9972 - val_loss: 0.0592 - val_accuracy: 0.9869
# Epoch 9/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0100 - accuracy: 0.9970 - val_loss: 0.0519 - val_accuracy: 0.9878
# Epoch 10/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0686 - val_accuracy: 0.9880
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_27 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 100)               102500
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 159,254
# Trainable params: 159,254
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 22s 14ms/step - loss: 0.1257 - accuracy: 0.9613 - val_loss: 0.0519 - val_accuracy: 0.9850
# Epoch 2/10
# 1500/1500 [==============================] - 22s 14ms/step - loss: 0.0425 - accuracy: 0.9867 - val_loss: 0.0461 - val_accuracy: 0.9869
# Epoch 3/10
# 1500/1500 [==============================] - 22s 14ms/step - loss: 0.0312 - accuracy: 0.9904 - val_loss: 0.0427 - val_accuracy: 0.9875
# Epoch 4/10
# 1500/1500 [==============================] - 22s 14ms/step - loss: 0.0225 - accuracy: 0.9928 - val_loss: 0.0348 - val_accuracy: 0.9894
# Epoch 5/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0192 - accuracy: 0.9940 - val_loss: 0.0415 - val_accuracy: 0.9889
# Epoch 6/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.0422 - val_accuracy: 0.9886
# Epoch 7/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.0415 - val_accuracy: 0.9888
# Epoch 8/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0479 - val_accuracy: 0.9891
# Epoch 9/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0095 - accuracy: 0.9970 - val_loss: 0.0465 - val_accuracy: 0.9893
# Epoch 10/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0082 - accuracy: 0.9974 - val_loss: 0.0398 - val_accuracy: 0.9905
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 100)               102500
# _________________________________________________________________
# dense_21 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 159,254
# Trainable params: 159,254
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.1327 - accuracy: 0.9584 - val_loss: 0.0504 - val_accuracy: 0.9862
# Epoch 2/10
# 1500/1500 [==============================] - 22s 14ms/step - loss: 0.0463 - accuracy: 0.9857 - val_loss: 0.0436 - val_accuracy: 0.9877
# Epoch 3/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0303 - accuracy: 0.9902 - val_loss: 0.0371 - val_accuracy: 0.9898
# Epoch 4/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0229 - accuracy: 0.9925 - val_loss: 0.0414 - val_accuracy: 0.9888
# Epoch 5/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0165 - accuracy: 0.9944 - val_loss: 0.0607 - val_accuracy: 0.9868
# Epoch 6/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.0407 - val_accuracy: 0.9902
# Epoch 7/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 0.0481 - val_accuracy: 0.9896
# Epoch 8/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 0.0484 - val_accuracy: 0.9900
# Epoch 9/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0084 - accuracy: 0.9971 - val_loss: 0.0550 - val_accuracy: 0.9893
# Epoch 10/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.0489 - val_accuracy: 0.9906
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_33 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 100)               102500
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 159,254
# Trainable params: 159,254
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.1308 - accuracy: 0.9600 - val_loss: 0.0699 - val_accuracy: 0.9794
# Epoch 2/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0477 - accuracy: 0.9851 - val_loss: 0.0459 - val_accuracy: 0.9856
# Epoch 3/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0308 - accuracy: 0.9905 - val_loss: 0.0362 - val_accuracy: 0.9883
# Epoch 4/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0245 - accuracy: 0.9921 - val_loss: 0.0339 - val_accuracy: 0.9902
# Epoch 5/10
# 1500/1500 [==============================] - 33s 22ms/step - loss: 0.0180 - accuracy: 0.9940 - val_loss: 0.0374 - val_accuracy: 0.9898
# Epoch 6/10
# 1500/1500 [==============================] - 150s 100ms/step - loss: 0.0152 - accuracy: 0.9950 - val_loss: 0.0336 - val_accuracy: 0.9912
# Epoch 7/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0121 - accuracy: 0.9962 - val_loss: 0.0464 - val_accuracy: 0.9883
# Epoch 8/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0105 - accuracy: 0.9964 - val_loss: 0.0380 - val_accuracy: 0.9909
# Epoch 9/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.0315 - val_accuracy: 0.9923
# Epoch 10/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.0365 - val_accuracy: 0.9913
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 100)               102500
# _________________________________________________________________
# dense_25 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 159,254
# Trainable params: 159,254
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.1250 - accuracy: 0.9613 - val_loss: 0.0552 - val_accuracy: 0.9833
# Epoch 2/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0442 - accuracy: 0.9861 - val_loss: 0.0493 - val_accuracy: 0.9844
# Epoch 3/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0296 - accuracy: 0.9909 - val_loss: 0.0421 - val_accuracy: 0.9870
# Epoch 4/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0234 - accuracy: 0.9926 - val_loss: 0.0359 - val_accuracy: 0.9890
# Epoch 5/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0180 - accuracy: 0.9945 - val_loss: 0.0350 - val_accuracy: 0.9908
# Epoch 6/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0130 - accuracy: 0.9958 - val_loss: 0.0411 - val_accuracy: 0.9887
# Epoch 7/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0109 - accuracy: 0.9964 - val_loss: 0.0479 - val_accuracy: 0.9895
# Epoch 8/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0112 - accuracy: 0.9960 - val_loss: 0.0459 - val_accuracy: 0.9910
# Epoch 9/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0081 - accuracy: 0.9974 - val_loss: 0.0499 - val_accuracy: 0.9893
# Epoch 10/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.0471 - val_accuracy: 0.9901
# Accuracy: mean=99.010 std=0.112, n=5
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_39 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 11, 11, 64)        18496
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 9, 9, 64)          36928
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_26 (Dense)             (None, 100)               102500
# _________________________________________________________________
# dense_27 (Dense)             (None, 10)                1010
# =================================================================
# Total params: 159,254
# Trainable params: 159,254
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 300/300 [==============================] - 20s 67ms/step - loss: 0.1872 - accuracy: 0.9426 - val_loss: 0.0745 - val_accuracy: 0.9766
# Epoch 2/10
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0500 - accuracy: 0.9847 - val_loss: 0.0434 - val_accuracy: 0.9860
# Epoch 3/10
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0351 - accuracy: 0.9889 - val_loss: 0.0336 - val_accuracy: 0.9889
# Epoch 4/10
# 300/300 [==============================] - 21s 69ms/step - loss: 0.0250 - accuracy: 0.9921 - val_loss: 0.0335 - val_accuracy: 0.9886
# Epoch 5/10
# 300/300 [==============================] - 21s 71ms/step - loss: 0.0210 - accuracy: 0.9931 - val_loss: 0.0338 - val_accuracy: 0.9890
# Epoch 6/10
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.0375 - val_accuracy: 0.9892
# Epoch 7/10
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0120 - accuracy: 0.9962 - val_loss: 0.0341 - val_accuracy: 0.9898
# Epoch 8/10
# 300/300 [==============================] - 19s 65ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.0354 - val_accuracy: 0.9901
# Epoch 9/10
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0093 - accuracy: 0.9966 - val_loss: 0.0324 - val_accuracy: 0.9917
# Epoch 10/10
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 0.0360 - val_accuracy: 0.9902
# Predicted digit: 0
# Predicted digit: 4
# Predicted digit: 1
# Predicted digit: 9
# Saved model to disk
